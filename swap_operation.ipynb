# %%
from libs import *

# %%
# %run QDirac2.ipynb

# %% [markdown]
# **Swap Gate/operation**

# %%
qc = QuantumCircuit(4)
# Out:
# Initialize by <instance>.init()

# %%
qc.init()

# %%
sv1 = qc.state_vector()

# %%
qc.X(1)

# %%
qc.swap(1, 2)

# %%
sv2 = qc.state_vector()

# %%
qc.draw()
