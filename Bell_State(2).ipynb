# %%
from libs import *

# %%
# %run QDirac2.ipynb

# %%
#########------------------------------------------------#########

# %%
qc = QuantumCircuit(2)
# Out:
# Initialize by <instance>.init()

# %%
qc.init()

# %%
qc.draw()

# %%
sv1 = qc.state_vector()
sv1
# Out:
# array([[1.],
#        [0.],
#        [0.],
#        [0.]])

# %%
qc.H(0)

# %%
qc.draw()

# %%
qc.state_vector()
# Out:
# array([[0.70710678],
#        [0.        ],
#        [0.70710678],
#        [0.        ]])

# %%
reduce(kron, [KET_XP, KET_0])
# Out:
# array([[0.70710678],
#        [0.        ],
#        [0.70710678],
#        [0.        ]])

# %%
qc.CX(0, 1)

# %%
qc.draw()

# %%
#measured_result = qc.measure()

# %%
qc.state_vector()
# Out:
# array([[0.70710678],
#        [0.        ],
#        [0.        ],
#        [0.70710678]])

# %%
qc.draw()
